# %%
# Use to import pandas (data manipulation)
import pandas as pd
import numpy as np
# Data visualization
import seaborn as sns
import matplotlib.pyplot as plt
# Use to import the file into google Colab drive
from google.colab import files 
# Use to import io, which opens the file from the Colab drive
import io
print ('Modules Imported')
# Out:
# Modules Imported

# %%
# This will open a widget when run that will enable you to browse the files on your local storage drive.
# IMPORT THE CORONA DATASET
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0dc1e242-7570-47fc-8d7c-62ab69dadd19" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0dc1e242-7570-47fc-8d7c-62ab69dadd19">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving covid19_Confirmed_dataset.csv to covid19_Confirmed_dataset (2).csv

# %%
corona_df = pd.read_csv ('covid19_Confirmed_dataset.csv')

# %%
corona_df.head (10)
# Out:
#                  Province/State       Country/Region  ...  4/29/20  4/30/20
# 0                           NaN          Afghanistan  ...     1939     2171
# 1                           NaN              Albania  ...      766      773
# 2                           NaN              Algeria  ...     3848     4006
# 3                           NaN              Andorra  ...      743      745
# 4                           NaN               Angola  ...       27       27
# 5                           NaN  Antigua and Barbuda  ...       24       24
# 6                           NaN            Argentina  ...     4285     4428
# 7                           NaN              Armenia  ...     1932     2066
# 8  Australian Capital Territory            Australia  ...      106      106
# 9               New South Wales            Australia  ...     3016     3025
#
# [10 rows x 104 columns]

# %%
corona_df.tail (10)
# Out:
#                        Province/State         Country/Region  ...  4/29/20  4/30/20
# 256  Bonaire, Sint Eustatius and Saba            Netherlands  ...        5        5
# 257                               NaN                 Malawi  ...       36       37
# 258       Falkland Islands (Malvinas)         United Kingdom  ...       13       13
# 259         Saint Pierre and Miquelon                 France  ...        1        1
# 260                               NaN            South Sudan  ...       34       35
# 261                               NaN         Western Sahara  ...        6        6
# 262                               NaN  Sao Tome and Principe  ...        8       14
# 263                               NaN                  Yemen  ...        6        6
# 264                               NaN                Comoros  ...        0        1
# 265                               NaN             Tajikistan  ...        0       15
#
# [10 rows x 104 columns]

# %%
corona_df.shape
# Out:
# (266, 104)

# %%
corona_df.describe ()
# Out:
#               Lat        Long  ...       4/29/20       4/30/20
# count  266.000000  266.000000  ...  2.660000e+02  2.660000e+02
# mean    21.259359   22.432499  ...  1.191693e+04  1.224378e+04
# std     24.747943   70.478908  ...  6.918917e+04  7.102980e+04
# min    -51.796300 -135.000000  ...  0.000000e+00  0.000000e+00
# 25%      6.907750  -18.093125  ...  7.600000e+01  7.725000e+01
# 50%     23.488100   20.921188  ...  4.555000e+02  4.665000e+02
# 75%     41.143200   77.191525  ...  2.047250e+03  2.105250e+03
# max     71.706900  178.065000  ...  1.039909e+06  1.069424e+06
#
# [8 rows x 102 columns]

# %%
corona_df.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Columns: 104 entries, Province/State to 4/30/20
# dtypes: float64(2), int64(100), object(2)
# memory usage: 216.2+ KB

# %% [markdown]
# ***Drop Futile Columns***

# %%
# Default values of axis is 0
df = corona_df.drop (['Lat','Long'], axis = 1)   # axis = 1 as we want to delete the columns
df
# Out:
#     Province/State         Country/Region  1/22/20  ...  4/28/20  4/29/20  4/30/20
# 0              NaN            Afghanistan        0  ...     1828     1939     2171
# 1              NaN                Albania        0  ...      750      766      773
# 2              NaN                Algeria        0  ...     3649     3848     4006
# 3              NaN                Andorra        0  ...      743      743      745
# 4              NaN                 Angola        0  ...       27       27       27
# ..             ...                    ...      ...  ...      ...      ...      ...
# 261            NaN         Western Sahara        0  ...        6        6        6
# 262            NaN  Sao Tome and Principe        0  ...        8        8       14
# 263            NaN                  Yemen        0  ...        1        6        6
# 264            NaN                Comoros        0  ...        0        0        1
# ...

# %%
# We set inplace parameter to be TRUE to drop the columns instantly, without returning a new dataframe.
corona_df.drop (['Lat','Long'], axis = 1, inplace = True)
corona_df
# Out:
#     Province/State         Country/Region  1/22/20  ...  4/28/20  4/29/20  4/30/20
# 0              NaN            Afghanistan        0  ...     1828     1939     2171
# 1              NaN                Albania        0  ...      750      766      773
# 2              NaN                Algeria        0  ...     3649     3848     4006
# 3              NaN                Andorra        0  ...      743      743      745
# 4              NaN                 Angola        0  ...       27       27       27
# ..             ...                    ...      ...  ...      ...      ...      ...
# 261            NaN         Western Sahara        0  ...        6        6        6
# 262            NaN  Sao Tome and Principe        0  ...        8        8       14
# 263            NaN                  Yemen        0  ...        1        6        6
# 264            NaN                Comoros        0  ...        0        0        1
# ...

# %% [markdown]
# ***Aggregating the rows by country***

# %%
'''We perform aggregation as in each row of our dataframe we had data related to each province in each country, but for our analysis we needed number of confirmed cases related to each country.'''
corona_df_aggregated = corona_df.groupby('Country/Region').sum()
corona_df_aggregated
# Out:
#                     1/22/20  1/23/20  1/24/20  ...  4/28/20  4/29/20  4/30/20
# Country/Region                                 ...
# Afghanistan               0        0        0  ...     1828     1939     2171
# Albania                   0        0        0  ...      750      766      773
# Algeria                   0        0        0  ...     3649     3848     4006
# Andorra                   0        0        0  ...      743      743      745
# Angola                    0        0        0  ...       27       27       27
# ...                     ...      ...      ...  ...      ...      ...      ...
# West Bank and Gaza        0        0        0  ...      343      344      344
# Western Sahara            0        0        0  ...        6        6        6
# Yemen                     0        0        0  ...        1        6        6
# Zambia                    0        0        0  ...       95       97      106
# ...

# %% [markdown]
# ***VISUALIZING DATA RELATED TO A SPECIFIC COUNTRY***

# %%
# Locate the country using loc & then use plot () method for a scatter plot
corona_df_aggregated.loc ['India'].plot()
corona_df_aggregated.loc ['Italy'].plot()
corona_df_aggregated.loc ['China'].plot()
corona_df_aggregated.loc ['France'].plot()
corona_df_aggregated.loc ['Australia'].plot()
corona_df_aggregated.loc ['Spain'].plot()
# plt.legend () function will show which line represents which country
plt.legend()

# %%
# VISUALIZE THE PLOT OF CHINA FOR THE FIRST FIVE DAYS
corona_df_aggregated.loc ['China'][:5].plot()

# %% [markdown]
# ***CALCULATING A GOOD MEASURE***

# %%
# CHANGE IN INFECTION NUMBER OF EACH DAY
# diff() function calculates the DERIVATIVE
corona_df_aggregated.loc ['China'].diff().plot()
corona_df_aggregated.loc ['Italy'].diff().plot()
corona_df_aggregated.loc ['Spain'].diff().plot()

# %%
# MAX INFECTION RATE OF CHINA, ITALY & SPAIN
corona_df_aggregated.loc ['China'].diff().max()
# Out:
# 15136.0

# %%
corona_df_aggregated.loc ['Italy'].diff().max()
# Out:
# 6557.0

# %%
corona_df_aggregated.loc ['India'].diff().max()
# Out:
# 1893.0

# %%
corona_df_aggregated.loc ['Spain'].diff().max()
# Out:
# 9630.0

# %%
# INDICES OF THIS DF - COUNTRIES
countries = list (corona_df_aggregated.index) # This will return the indices 
max_infected_rates = []
for c in countries :
  max_infected_rates.append (corona_df_aggregated.loc [c].diff().max()) # MAX INFECTION RATE OF ALL COUNTRIES 
# Directly append the numbers to the list using append () function
print (max_infected_rates)
# Out:
# [232.0,
#  34.0,
#  199.0,
#  43.0,
#  5.0,
#  6.0,
#  291.0,
#  134.0,
#  497.0,
#  1321.0,
#  105.0,
#  7.0,
#  301.0,
#  641.0,
#  12.0,
#  1485.0,
#  2454.0,
#  4.0,
#  19.0,
#  1.0,
#  104.0,
#  92.0,
#  7.0,
#  7502.0,
#  26.0,
#  137.0,
#  41.0,
#  21.0,
#  6.0,
#  45.0,
#  31.0,
#  203.0,
#  2778.0,
#  31.0,
#  21.0,
#  1138.0,
#  15136.0,
#  353.0,
#  1.0,
#  57.0,
#  81.0,
#  37.0,
#  113.0,
#  96.0,
#  63.0,
#  58.0,
#  381.0,
#  391.0,
#  99.0,
#  156.0,
#  5.0,
#  371.0,
#  11536.0,
#  269.0,
#  32.0,
#  130.0,
#  7.0,
#  134.0,
#  20.0,
#  9.0,
#  5.0,
#  267.0,
#  26849.0,
#  38.0,
#  5.0,
#  42.0,
#  6933.0,
#  403.0,
#  156.0,
#  6.0,
#  68.0,
#  167.0,
#  132.0,
#  12.0,
#  10.0,
#  3.0,
#  72.0,
#  210.0,
#  99.0,
#  1893.0,
#  436.0,
#  3186.0,
#  91.0,
#  1515.0,
#  1131.0,
#  6557.0,
#  52.0,
#  1161.0,
#  40.0,
#  264.0,
#  29.0,
#  851.0,
#  289.0,
#  300.0,
#  69.0,
#  3.0,
#  48.0,
#  61.0,
#  17.0,
#  13.0,
#  21.0,
#  90.0,
#  234.0,
#  7.0,
#  14.0,
# ...

# %%
# MAX INFECTION RATE OF ALL COUNTRIES (numbers & names)
corona_df_aggregated ['max_infected_rates'] = max_infected_rates
print (corona_df_aggregated)
# Out:
#                     1/22/20  1/23/20  ...  4/30/20  max_infected_rates
# Country/Region                        ...
# Afghanistan               0        0  ...     2171               232.0
# Albania                   0        0  ...      773                34.0
# Algeria                   0        0  ...     4006               199.0
# Andorra                   0        0  ...      745                43.0
# Angola                    0        0  ...       27                 5.0
# ...                     ...      ...  ...      ...                 ...
# West Bank and Gaza        0        0  ...      344                66.0
# Western Sahara            0        0  ...        6                 4.0
# Yemen                     0        0  ...        6                 5.0
# Zambia                    0        0  ...      106                 9.0
# Zimbabwe                  0        0  ...       40                 8.0
#
# [187 rows x 101 columns]

# %% [markdown]
# ***NEW DF WITH USEFUL COLUMNS ONLY***

# %%
corona_data = pd.DataFrame (corona_df_aggregated ['max_infected_rates'])
corona_data
# Out:
#                     max_infected_rates
# Country/Region
# Afghanistan                      232.0
# Albania                           34.0
# Algeria                          199.0
# Andorra                           43.0
# Angola                             5.0
# ...                                ...
# West Bank and Gaza                66.0
# Western Sahara                     4.0
# Yemen                              5.0
# Zambia                             9.0
# Zimbabwe                           8.0
#
# [187 rows x 1 columns]

# %%
# IMPORT THE WORLDWIDE HAPPINESS REPORT DATASET 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ba3ad3af-0ec5-4abf-b120-72fe5c4e85a2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ba3ad3af-0ec5-4abf-b120-72fe5c4e85a2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving worldwide_happiness_report.csv to worldwide_happiness_report.csv

# %%
worldwide_happiness_report = pd.read_csv ('worldwide_happiness_report.csv')
worldwide_happiness_report
# Out:
#      Overall rank  ... Perceptions of corruption
# 0               1  ...                     0.393
# 1               2  ...                     0.410
# 2               3  ...                     0.341
# 3               4  ...                     0.118
# 4               5  ...                     0.298
# ..            ...  ...                       ...
# 151           152  ...                     0.411
# 152           153  ...                     0.147
# 153           154  ...                     0.025
# 154           155  ...                     0.035
# 155           156  ...                     0.091
#
# [156 rows x 9 columns]

# %% [markdown]
# ***DROP FUTILE COLUMNS***

# %%
worldwide_happiness_report.drop (['Freedom to make life choices','Generosity','Perceptions of corruption'], axis = 1, inplace = True)
worldwide_happiness_report
# Out:
#      Overall rank  ... Healthy life expectancy
# 0               1  ...                   0.986
# 1               2  ...                   0.996
# 2               3  ...                   1.028
# 3               4  ...                   1.026
# 4               5  ...                   0.999
# ..            ...  ...                     ...
# 151           152  ...                   0.614
# 152           153  ...                   0.499
# 153           154  ...                   0.361
# 154           155  ...                   0.105
# 155           156  ...                   0.295
#
# [156 rows x 6 columns]

# %%
# CHANGE INDICES OF THE DF USING set_index 
worldwide_happiness_report.set_index ('Country or region', inplace = True)
worldwide_happiness_report
# Out:
#                           Overall rank  ...  Healthy life expectancy
# Country or region                       ...
# Finland                              1  ...                    0.986
# Denmark                              2  ...                    0.996
# Norway                               3  ...                    1.028
# Iceland                              4  ...                    1.026
# Netherlands                          5  ...                    0.999
# ...                                ...  ...                      ...
# Rwanda                             152  ...                    0.614
# Tanzania                           153  ...                    0.499
# Afghanistan                        154  ...                    0.361
# Central African Republic           155  ...                    0.105
# South Sudan                        156  ...                    0.295
#
# [156 rows x 5 columns]

# %% [markdown]
# ***USE INNER JOIN TO MERGE THE TWO DFs AS WE HAVE MORE DATA IN THE 1ST DF***

# %%
# How is used to specify which type of join
data = corona_data.join (worldwide_happiness_report, how = 'inner')
data
# Out:
#              max_infected_rates  ...  Healthy life expectancy
# Afghanistan               232.0  ...                    0.361
# Albania                    34.0  ...                    0.874
# Algeria                   199.0  ...                    0.785
# Argentina                 291.0  ...                    0.881
# Armenia                   134.0  ...                    0.815
# ...                         ...  ...                      ...
# Venezuela                  29.0  ...                    0.805
# Vietnam                    19.0  ...                    0.851
# Yemen                       5.0  ...                    0.463
# Zambia                      9.0  ...                    0.426
# Zimbabwe                    8.0  ...                    0.433
#
# [143 rows x 6 columns]

# %% [markdown]
# ***CORRELATION MATRIX***

# %%
data.corr ()
# Out:
#                          max_infected_rates  ...  Healthy life expectancy
# max_infected_rates                 1.000000  ...                 0.289263
# Overall rank                      -0.244777  ...                -0.804753
# Score                              0.228783  ...                 0.799893
# GDP per capita                     0.250118  ...                 0.863062
# Social support                     0.191958  ...                 0.765286
# Healthy life expectancy            0.289263  ...                 1.000000
#
# [6 rows x 6 columns]

# %% [markdown]
# ***VISUALIZATION OF THE RESULTS***

# %% [markdown]
# ****PLOTTING GDP VS MAX INFECTION RATE****

# %%
x_axis = data ['GDP per capita']
y_axis = data ['max_infected_rates']
sns.scatterplot (x_axis,np.log(y_axis))  # Log Scaling

'''We can see, there is a +ve correlation between both the axis. 
As GDP per capita increases, max_infected_rates increases.
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# regplot() is used to plot data and a linear regression model fit.
sns.regplot (x_axis,np.log(y_axis))
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ***PLOTTING SOCIAL SUPPORT VS MAX INFECTION RATE***

# %%
x_axis = data ['Social support']
y_axis = data ['max_infected_rates']
sns.regplot (x_axis,np.log(y_axis))
'''We can observe that citizens of the developed countries are more prone to be infected'''
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ***PLOTTING HEALTHY LIFE EXPECTANCY VS MAX INFECTION RATE***

# %%
x_axis = data ['Healthy life expectancy']
y_axis = data ['max_infected_rates']
sns.regplot (x_axis,np.log(y_axis))
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
